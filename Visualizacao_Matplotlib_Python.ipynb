# %%
import pandas as pd

# %%
df = pd.read_csv("monitoramento_tempo.csv")

# %%
df.head()
# Out:
#    temperatura  pressão  ...  dia_da_semana                 data
# 0   282.080000   1024.0  ...        Domingo  2012-10-01 12:00:00
# 1   282.080000   1024.0  ...        Domingo  2012-10-01 13:00:00
# 2   282.083252   1024.0  ...        Domingo  2012-10-01 14:00:00
# 3   282.091866   1024.0  ...        Domingo  2012-10-01 15:00:00
# 4   282.100481   1024.0  ...        Domingo  2012-10-01 16:00:00
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df["data"] = pd.to_datetime(df["data"])

# %% [markdown]
# ## Conversão de objeto para datetime em df["data"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(8,5))
plt.plot(df["data"], df["temperatura"])
plt.title("Temperatura Anual")
plt.xlabel("Ano")
plt.ylabel("Temperatura")
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"])
eixo.set_title("Temperatura no tempo")
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"])
eixo.set_title("Temperatura no tempo", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 10)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"], color = "orange")
eixo.set_title("Temperatura no tempo", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 10)

# %% [markdown]
# ##**Customizando**

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"],
          color = "orange",
          ls = "dotted") # Estilo da linha 
eixo.set_title("Temperatura no tempo", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 10)

# %%
import datetime

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"], color = "orange")

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1)) #Delimitando intervalo
eixo.set_title("Temperatura no tempo", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 10)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"], color = "orange", marker = "o") # Adicionando Marker

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title("Temperatura no tempo", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 10)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.plot(df["data"], df["temperatura"], color = "orange")

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title("Temperatura no tempo", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 20)
eixo.grid(True) # Adicionando grid

# %% [markdown]
# ---

# %% [markdown]
# ##**Mais de um eixo na mesma visualização**

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.1, 0.5, 0.4, 0.4])

eixo.grid(True)
eixo.plot(df["data"], df["temperatura"], color = "g")
eixo.set_title("Temperatura no tempo", pad = 20)
eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.legend(["Temperatura"], loc = "best", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
#####################################################################3

eixo2.plot(df["data"], df["temperatura"], color = "orange")
eixo2.set_title("Temperatura no tempo", pad = 20)
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.legend(["Temperatura"], loc = "best", fontsize = 8)
eixo2.set_xlabel("Ano", fontsize = 8)
eixo2.set_ylabel("Temperatura", fontsize = 8)
# Out:
# Text(0, 0.5, 'Temperatura')

# %% [markdown]
# ##**Ajustando posição Eixo 2**

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df["data"], df["temperatura"], color = "g")
eixo.set_title("Temperatura no tempo", pad = 20)
eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.legend(["Temperatura"], loc = "best", fontsize = 20)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
#####################################################################3

eixo2.plot(df["data"], df["temperatura"], color = "orange")
eixo2.set_title("Temperatura em 2014", pad = 20)
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.legend(["Temperatura"], loc = "best", fontsize = 8)
eixo2.set_xlabel("Ano", fontsize = 8)
eixo2.set_ylabel("Temperatura", fontsize = 8)
# Out:
# Text(0, 0.5, 'Temperatura')

# %% [markdown]
# ##**Visualização mais complexa**

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df["data"], df["temperatura"], color = "g")
eixo.set_title("Temperatura Maio/2014", pad = 20, fontsize = 25)
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.legend(["Temperatura Maio/2014"], loc = "lower right", fontsize = 15)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)
#####################################################################3

eixo2.plot(df["data"], df["temperatura"], color = "orange")
eixo2.set_title("Temperatura 2014", fontsize = 15)
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.legend(["Temperatura"], loc = "best", fontsize = 8)
eixo2.set_xlabel("Ano", fontsize = 8)
eixo2.set_ylabel("Temperatura", fontsize = 8)
# Out:
# Text(0, 0.5, 'Temperatura')

# %% [markdown]
# ##**Aplicando Filtro**

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df["data"], df["temperatura"], color = "g")
eixo.set_title("Temperatura Maio/2014", pad = 20, fontsize = 25)
eixo.set_xlim(datetime.datetime(2014,5,1), datetime.datetime(2014,6,1))
eixo.set_ylim(270, 320)
eixo.legend(["Temperatura Maio/2014"], loc = "lower right", fontsize = 15)
eixo.set_xlabel("Ano", fontsize = 16)
eixo.set_ylabel("Temperatura", fontsize = 16)

azul_esquerda = df["data"] < datetime.datetime(2014,5,1)
azul_direita = df["data"] > datetime.datetime(2014,6,1)
#####################################################################

eixo2.plot(df["data"], df["temperatura"], color = "g")
eixo2.plot(df[azul_esquerda]["data"], df[azul_esquerda]["temperatura"], color = "b")
eixo2.plot(df[azul_direita]["data"], df[azul_direita]["temperatura"], color = "b")
eixo2.set_title("Temperatura 2014", fontsize = 11)
eixo2.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo2.legend(["Temperatura"], loc = "best", fontsize = 8)
eixo2.set_xlabel("Ano", fontsize = 8)
eixo2.set_ylabel("Temperatura", fontsize = 8)
# Out:
# Text(0, 0.5, 'Temperatura')

# %% [markdown]
# ##**Linhas de Restrição e Anotações**

# %%
import numpy as np
media = np.mean(df["temperatura"])
mediana = np.median(df["temperatura"])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df["data"], df["temperatura"], color = "green")
eixo.set_title("Temperatura Ano", fontsize = 25, pad = 20)
eixo.set_xlabel("Ano", fontsize = 20)
eixo.set_ylabel("Temperatura", fontsize = 20)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 15)
eixo.grid("True")

################################################
x1 = df["data"][df["temperatura"].idxmax()]
y1 = max(df["temperatura"])
################################################

eixo.annotate("Temperatura Máxima", xy =(x1,y1), fontsize = 16)

eixo.axhline(max(df["temperatura"]), color = "k", linestyle = "--")
eixo.axhline(min(df["temperatura"]), color = "k", linestyle = "--")
eixo.axhline(media, color = "red")
eixo.axhline(mediana, color = "fuchsia")

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])

eixo.plot(df["data"], df["temperatura"], color = "green")
eixo.set_title("Temperatura Ano", fontsize = 25, pad = 20)
eixo.set_xlabel("Ano", fontsize = 20)
eixo.set_ylabel("Temperatura", fontsize = 20)
eixo.legend(["Temperatura"], loc = "lower right", fontsize = 15)
eixo.grid("True")

# Estabelecendo eixos da legenda de Temperatura Máxima
################################################
x1 = df["data"][df["temperatura"].idxmax()]
y1 = max(df["temperatura"])

x2 = df["data"][df["temperatura"].idxmax() - 7000] # menos 7.000 horas0
y2 = max(df["temperatura"]) - 5

eixo.annotate("Temperatura Máxima", 
              xy =(x1,y1), 
              fontsize = 16, 
              xytext = (x2, y2),
              arrowprops = dict(facecolor = "k"))

# Estabelecendo eixos da legenda de Temperatura Mínima
x1 = df["data"][df["temperatura"].idxmin()]
y1 = min(df["temperatura"])

x2 = df["data"][df["temperatura"].idxmin() - 7000] # menos 7.000 horas0
y2 = min(df["temperatura"]) + 5

eixo.annotate("Temperatura Min", 
              xy =(x1,y1), 
              fontsize = 16, 
              xytext = (x2, y2),
              arrowprops = dict(facecolor = "k"))

eixo.axhline(max(df["temperatura"]), color = "k", linestyle = "--")
eixo.axhline(min(df["temperatura"]), color = "k", linestyle = "--")
eixo.axhline(media, color = "red")
eixo.axhline(mediana, color = "fuchsia")

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ["Domingo", "Segunda", "Terça", "Quarta", "Quinta", "Sexta", "Sábado"]
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias] # nova atribuição
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %% [markdown]
# ##**Barras**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'r', 'g', 'b', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores, edgecolor='black')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(0, 0, 'Segunda'),
#  Text(0, 0, 'Terça'),
#  Text(0, 0, 'Quarta'),
#  Text(0, 0, 'Quinta'),
#  Text(0, 0, 'Sexta'),
#  Text(0, 0, 'Sábado')]

# %% [markdown]
# ##**Pizza**

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1, 0, 0, 0, 0, 0.1, 0.1]

eixo.pie(temperatura_por_dia_da_semana, labels=temperatura_por_dia_da_semana.index,
         autopct='%.1f%%', explode=explodir)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %% [markdown]
# ##**Dispersão Iris**

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    comprimento_sépala  largura_sépala  ...  largura_pétala      espécie
# 0                 5.1             3.5  ...             0.2  Iris-setosa
# 1                 4.9             3.0  ...             0.2  Iris-setosa
# 2                 4.7             3.2  ...             0.2  Iris-setosa
# 3                 4.6             3.1  ...             0.2  Iris-setosa
# 4                 5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
fig = plt.figure(figsize=(15,8))

ax = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'r', 
         'Iris-versicolor': 'b', 
         'Iris-virginica': 'g'}

marcadores = {'Iris-setosa': 'x',
              'Iris-versicolor': 'o',
              'Iris-virginica': 'v'}

for especie in df['espécie'].unique(): # espécies unicas da coluna
    tmp = df[df['espécie'] == especie] # dataframe temporário que servirá de filtro dentro do loop

    ax.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
               color=cores[especie], marker=marcadores[especie], s=100)

ax.set_title('Gráfico de dispersão', fontsize=25, pad=15)
ax.set_xlabel('Comprimento da sépala', fontsize=15)
ax.set_ylabel('Largura da sépala', fontsize=15)

ax.tick_params(labelsize=15)
ax.legend(cores, fontsize=20)

# %% [markdown]
# ##**Boxplots**

# %%
fig = plt.figure(figsize=(5,4))
ax = fig.add_axes([0,0,1,1])

ax.boxplot(df["largura_pétala"])
ax.set_title("Boxplot", fontsize=15, pad=10)
ax.set_xticklabels(["largura_pétala"])
# Out:
# [Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(5,4))
ax = fig.add_axes([0,0,1,1])

ax.boxplot(df.drop("espécie", axis =1).values, patch_artist = True)# dataframe torna um array e cor
ax.set_title("Boxplot", fontsize=15, pad=10)
ax.set_xticklabels(df.drop('espécie', axis=1).columns)
# Out:
# [Text(0, 0, 'comprimento_sépala'),
#  Text(0, 0, 'largura_sépala'),
#  Text(0, 0, 'comprimento_pétala'),
#  Text(0, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(5,4))
ax = fig.add_axes([0,0,1,1])

cores = ['red', 'blue', 'orange', 'green']

boxes = ax.boxplot(df.drop("espécie", axis =1).values, patch_artist = True)# dataframe torna um array e cor
ax.set_title("Boxplot", fontsize=15, pad=10)
ax.set_xticklabels(df.drop('espécie', axis=1).columns)

for box, cor in zip(boxes['boxes'], cores):
    box.set(color=cor) #associar cada caixa em uma cor

for outlier in boxes['fliers']:
    outlier.set(marker='x', markersize = 8)

# %%
fig = plt.figure(figsize = (5,4))
ax = fig.add_axes([0,0,1,1])

ax.hist(df['comprimento_pétala'], bins = 20, orientation = "horizontal" )
ax.set_title('Histograma', fontsize=15, pad=10)
ax.set_xlabel('Comprimento de Pétala', fontsize = 15)
ax.grid(True)

# %%
fig = plt.figure(figsize = (5,4))
ax = fig.add_axes([0,0,1,1])

ax.hist(df['comprimento_pétala'], bins = 20, density = True)
ax.set_title('Histograma', fontsize=15, pad=10)
ax.set_xlabel('Comprimento de Pétala', fontsize = 15)
ax.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
ax = fig.add_axes([0, 0, 1, 1])

mu, sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

ax.hist(df['comprimento_pétala'], bins = 20)
ax.set_title('Histograma', fontsize=15, pad=10)
ax.set_xlabel('Comprimento de pétala', fontsize=15)
ax.grid(True)

ax.annotate('mu = {0:.2f}\nsigma = {1:.2f}'.format(mu,sigma),
            xy=(4.5, 20), fontsize=20)
# Out:
# Text(4.5, 20, 'mu = 3.76\nsigma = 1.76')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_is = df[df['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'], bins = 10)
eixo.grid(True)
eixo.set_title('Histograma Iris Setosa', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma={1:.2f}$'.format(mu, sigma), 
              xy=(1.7, 7), fontsize=20)

eixo.annotate('média', xy=(df_is['comprimento_pétala'].mean()-0.2, 13.5), fontsize=20)
eixo.axvline(df_is['comprimento_pétala'].mean(), color='k', linestyle='--')

eixo.annotate('mediana', xy=(df_is['comprimento_pétala'].median()+0.05, 12), fontsize=20, color = 'g')
eixo.axvline(df_is['comprimento_pétala'].median(), color='g', linestyle='--')

fig.savefig('histograma_is.png', bbox_inches='tight')
